# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickMoraesCutrim/datascience-m1/blob/main/C_aperfei%C3%A7oamento_analise_de_dados_modulo_1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo I

# %% [markdown]
# ## Unidade I

# %% [markdown]
# > Somente Contextualização

# %% [markdown]
# ## Unidade II

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/populacao_estados_2022_pib_2023.xlsx')
df.head()
# Out:
#      Estado    Região  População           PIB
# 0      Acre     Norte     829780   21374000000
# 1   Alagoas  Nordeste    3125254   76266000000
# 2     Amapá     Norte     774268   20100000000
# 3  Amazonas     Norte    3952262  131531000000
# 4     Bahia  Nordeste   14659023  352618000000

# %%
print(df.População.sum())
# Out:
# 207750291

# %%
print(df.PIB.sum())
# Out:
# 9012144000000

# %%
df.groupby(by='Região').sum()['População'].plot(kind = 'bar', color='black')
# Out:
# <Axes: xlabel='Região'>

# %% [markdown]
# Tipo de Dado
#
# * tuple	Sequência imutável de elementos	tupla = (1, 2, 3)
# * list	Sequência mutável de elementos	lista = [1, 2, 3, 4]
# * dict	Coleção de pares chave-valor	dicionario[rb1]  = {'chave': 'valor'}
# * set	Coleção não ordenada de elementos únicos	conjunto = {1, 2, 3}

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %% [markdown]
# > Aqui basicamente criamos 2 arrays através de duas listas, agora vamos fazer algumas operações

# %%
a+b
# Out:
# array([5, 7, 9])

# %%
a-b
# Out:
# array([-3, -3, -3])

# %%
a*b
# Out:
# array([ 4, 10, 18])

# %%
a/b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
listah = [1, 'PAtrick',2.4]
listah
# Out:
# [1, 'PAtrick', 2.4]

# %% [markdown]
# > Vamos transformar essa lista em um array, basta ```np.array(lista)```

# %%
np.array(listah)
# Out:
# array(['1', 'PAtrick', '2.4'], dtype='<U32')

# %% [markdown]
# > Temos também arrays bidimensionais, também chamados de matrizes

# %%
array_2d = np.array([[1,2,3],[4,5,6]])
array_2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# > Podemos fazer algumas operações, como calcular a Matrix Transposta, soma e media

# %%
array_2d.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
soma = np.sum(array_2d)
# ou array_2d.sum()

# %%
media = np.mean(array_2d)
media
# Out:
# 3.5

# %% [markdown]
# podemos tamvém criar matrizes só com zeros ou com uns, usando np.ones ou np.zeros, pra definir o tamanho precisamos usar parenteses assim ficamos com np.ones((linhas,colunas)), assim como também, podemos criar numeros com o passo usando np.arange(inicio, fim , passo), ou até usar o proprio numpy para definir quais numeros vão ter de acordo com o numero que pedimos usando np.linspace(inicio, fim, numero de numeros que queremos)

# %%
np.ones((2,4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
np.zeros((2,4))
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0,2,5)
# Out:
# array([0. , 0.5, 1. , 1.5, 2. ])

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/populacao_estados_2022_pib_2023.xlsx')
df.head()
# Out:
#      Estado    Região  População           PIB
# 0      Acre     Norte     829780   21374000000
# 1   Alagoas  Nordeste    3125254   76266000000
# 2     Amapá     Norte     774268   20100000000
# 3  Amazonas     Norte    3952262  131531000000
# 4     Bahia  Nordeste   14659023  352618000000

# %%
df.Estado
# Out:
# 0                    Acre
# 1                 Alagoas
# 2                   Amapá
# 3                Amazonas
# 4                   Bahia
# 5                   Ceará
# 6        Distrito Federal
# 7          Espírito Santo
# 8                   Goiás
# 9                Maranhão
# 10            Mato Grosso
# 11     Mato Grosso do Sul
# 12           Minas Gerais
# 13                   Pará
# 14                Paraíba
# 15                 Paraná
# 16             Pernambuco
# 17                  Piauí
# 18         Rio de Janeiro
# 19    Rio Grande do Norte
# 20      Rio Grande do Sul
# 21               Rondônia
# 22                Roraima
# 23         Santa Catarina
# 24              São Paulo
# 25                Sergipe
# 26              Tocantins
# Name: Estado, dtype: object

# %%
df.Estado.head()
# Out:
# 0        Acre
# 1     Alagoas
# 2       Amapá
# 3    Amazonas
# 4       Bahia
# Name: Estado, dtype: object

# %% [markdown]
# > podemos localizar as linhas com o método iloc, usando df.iloc [ numero da linha ]

# %%
df.iloc[1]
# Out:
# Estado           Alagoas
# Região          Nordeste
# População        3125254
# PIB          76266000000
# Name: 1, dtype: object

# %% [markdown]
# > Para vermos dados de um estado especifico, podemos usar o df.set_index('Variavel de interesse',inplace=True)

# %%
df.set_index('Estado',inplace = True)

# %% [markdown]
# > Depois que definimos o nome do Estado como indice, vamos visualizar novamente o head do datframe

# %%
df.head()
# Out:
#             Região  População           PIB
# Estado
# Acre         Norte     829780   21374000000
# Alagoas   Nordeste    3125254   76266000000
# Amapá        Norte     774268   20100000000
# Amazonas     Norte    3952262  131531000000
# Bahia     Nordeste   14659023  352618000000

# %% [markdown]
# > Agora podemos acessar esses indices com o parametro df.index

# %%
df.index
# Out:
# Index(['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará',
#        'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão',
#        'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba',
#        'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro',
#        'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima',
#        'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins'],
#       dtype='object', name='Estado')

# %% [markdown]
# > E mais, podemos visualizar somente um desses idex, usando o .iloc['nome do indice']

# %%
df.loc['São Paulo']
# Out:
# Região             Sudeste
# População         46024937
# PIB          2719751000000
# Name: São Paulo, dtype: object

# %% [markdown]
# > Também temos outros métodos como o type, info, describe, dentre outros, para obtermos uma visão geral da nossa base de dados e possiveis insigths ou dúvidas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, Acre to Tocantins
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Região     27 non-null     object
#  1   População  27 non-null     int64
#  2   PIB        27 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#           População           PIB
# count  2.700000e+01  2.700000e+01
# mean   7.694455e+06  3.337831e+11
# std    9.226068e+06  5.356333e+11
# min    6.348050e+05  1.820300e+10
# 25%    2.878556e+06  7.014700e+10
# 50%    3.975100e+06  1.863370e+11
# 75%    8.993772e+06  3.197810e+11
# max    4.602494e+07  2.719751e+12

# %%
type("População")
# Out:
# str

# %% [markdown]
# > Podemos também fazer algumas operações como soma, media entre outros, populacao.sum()

# %%
df_filtrado = df.query('Região == "Nordeste"')
df_filtrado
# Out:
#                        Região  População           PIB
# Estado
# Alagoas              Nordeste    3125254   76266000000
# Bahia                Nordeste   14659023  352618000000
# Ceará                Nordeste    8936431  194885000000
# Maranhão             Nordeste    6800605  124981000000
# Paraíba              Nordeste    4030961   77470000000
# Pernambuco           Nordeste    9051113  220814000000
# Piauí                Nordeste    3270174   64028000000
# Rio Grande do Norte  Nordeste    3303953   80181000000
# Sergipe              Nordeste    2211868   51861000000

# %%
df_selecionado = df_filtrado[['População' , 'PIB']]
populacao = df_filtrado['População']
populacao
# Out:
# Estado
# Alagoas                 3125254
# Bahia                  14659023
# Ceará                   8936431
# Maranhão                6800605
# Paraíba                 4030961
# Pernambuco              9051113
# Piauí                   3270174
# Rio Grande do Norte     3303953
# Sergipe                 2211868
# Name: População, dtype: int64

# %%
populacao.sum()
# Out:
# 55389382

# %%
type(populacao)
# Out:
# pandas.core.series.Series

# %%
populacao.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 9 entries, Alagoas to Sergipe
# Series name: População
# Non-Null Count  Dtype
# --------------  -----
# 9 non-null      int64
# dtypes: int64(1)
# memory usage: 444.0+ bytes

# %% [markdown]
#  >Podemos realizar encadeamento de, para obter um resultado mais especifico, por exemplo, se quisermos somar a população somente da região Norte, podemos usar: `df.query('Região == "Norte"')['Populaação]sum()`

# %%
df.query('Região == "Norte"')['População'].sum()
# Out:
# 17834762

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >É importante destacar que podemos ter várias e diferentes transformações, não apenas 3 como na analogia. Por exemplo, no código a seguir, primeiramente os estados serão agrupados por região, em seguida para cada região serão somados os PIBs dos estados e, por fim, será retornado um gráfico de pizza.

# %%
df.groupby(by='Região')['PIB'].sum().plot(kind='pie');

# %% [markdown]
# > Agora vamos usar matplotlib.pyplot as plt, vamos chamar de plt

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['População'])

# %% [markdown]
# >Um gráfico de linhas seria uma boa opção para visualizar a evolução da população brasileira nos últimos 50 anos, por exemplo. Contudo, um gráfico de barras horizontais pode ser mais interessante para essa visualização, mas antes de gerar o gráfico, cria-se uma variável com a população ordenada:

# %%
populacao = df['População'].sort_values()
populacao
# Out:
# Estado
# Roraima                  634805
# Amapá                    774268
# Acre                     829780
# Tocantins               1584306
# Rondônia                1616379
# Sergipe                 2211868
# Mato Grosso do Sul      2833742
# Distrito Federal        2923369
# Alagoas                 3125254
# Piauí                   3270174
# Rio Grande do Norte     3303953
# Mato Grosso             3784239
# Amazonas                3952262
# Espírito Santo          3975100
# Paraíba                 4030961
# Maranhão                6800605
# Goiás                   6950976
# Santa Catarina          7762154
# Pará                    8442962
# Ceará                   8936431
# Pernambuco              9051113
# Rio Grande do Sul      11088065
# Paraná                 11835379
# Bahia                  14659023
# Rio de Janeiro         16615526
# Minas Gerais           20732660
# São Paulo              46024937
# Name: População, dtype: int64

# %% [markdown]
# >Agora, é possível criar um gráfico de barras com a função plt.barh:

# %%
plt.barh(populacao.index, populacao.values);

# %% [markdown]
# > Para explorar as possibilidades e a flexibilidade que a Matplotlib nos oferece, vamos apresentar um exemplo no qual exibimos dois gráficos lado a lado utilizando   subplots . Com subplots, você pode criar múltiplos gráficos em uma única figura, facilitando a comparação entre diferentes conjuntos de dados ou diferentes aspectos de um conjunto de dados.
#
#
# > O Pandas Series será utilizado com a população e o PIB, mas, anteriormente, o valor do PIB será convertido em bilhões para facilitar a leitura.

# %%
pib = (df['PIB']/1_000_000_000).sort_values()
pib
# Out:
# Estado
# Roraima                  18.203
# Amapá                    20.100
# Acre                     21.374
# Tocantins                51.781
# Sergipe                  51.861
# Rondônia                 58.170
# Piauí                    64.028
# Alagoas                  76.266
# Paraíba                  77.470
# Rio Grande do Norte      80.181
# Maranhão                124.981
# Amazonas                131.531
# Mato Grosso do Sul      142.204
# Espírito Santo          186.337
# Ceará                   194.885
# Pernambuco              220.814
# Mato Grosso             233.390
# Pará                    262.905
# Goiás                   269.628
# Distrito Federal        286.944
# Bahia                   352.618
# Santa Catarina          428.571
# Paraná                  549.973
# Rio Grande do Sul       581.284
# Minas Gerais            857.593
# Rio de Janeiro          949.301
# São Paulo              2719.751
# Name: PIB, dtype: float64

# %%
#CRIADNO A FIGURA SUBPLOTS
fig, axs = plt.subplots(1,2, figsize = (12,5))

#SUBPLOT 1
axs[0].barh(populacao.index,populacao.values, color = 'black')
axs[0].set_title('População dos estados')
axs[0].set_xlabel('População')

#SUBPLOT 2 -  gráficos de barras horizontais para PIB
axs[1].barh(pib.index,pib.values, color = 'Black')
axs[1].set_title('PB (em bilhões) por Estado')
axs[1].set_xlabel('PIB( em bilhões)')

# AJUSTANDO O LAYOUT
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Unidade III

# %% [markdown]
# ### Analisando os dados sobre os servidores da UFMA

# %% [markdown]
# > Agora vamos a mão na massa.
#
# Imagine que você seja um discente, docente ou técnico administrativo da Universidade Federal do Maranhão e, por isso, tem interesse em explorar os dados disponíveis no Portal de Dados Abertos dessa instituição

# %%
import pandas as pd

# %%
import ssl
import urllib.request
import pandas as pd

# Ignorar a verificação do certificado SSL
context = ssl._create_unverified_context()

# URL do arquivo CSV
url_2020 = "http://dadosabertos.ufma.br/dataset/334d89c8-629f-49c5-aa06-171e35c1d33b/resource/55a2d103-d73b-449e-85bc-655df7dfc45a/download/docentes_-_2020.csv"

# Abrir o URL e ler o CSV diretamente em um DataFrame
response = urllib.request.urlopen(url_2020, context=context)
df = pd.read_csv(response, sep =";")

# %% [markdown]
# >Qual é a quantidade de docentes e técnicos administrativos por unidade, sexo e titulação? A partir dos dados, seremos capazes de responder perguntas, como essa. Vamos analisar esses dados?

# %%
df.head()
# Out:
#                                nome  \
# 0  ALANA DAS CHAGAS FERREIRA AGUIAR
# 1    FREDERICO FERNANDO SOUZA SILVA
# 2     ANDREA MARQUES DA SILVA PIRES
# 3                SARA FITERMAN LIMA
# 4         ABIMAELSON SANTOS PEREIRA
#
#                                             unidade sexo  titulacao  \
# 0                     DEPARTAMENTO DE BIOLOGIA/CCBS    F  DOUTORADO
# 1                 DEPARTAMENTO DE ARTES VISUAIS/CCH    M  DOUTORADO
# 2                    DEPARTAMENTO DE PATOLOGIA/CCBS    F  DOUTORADO
# 3  COORDENACAO DO CURSO DE MEDICINA PINHEIRO/CCHNST    F  DOUTORADO
# 4                 DEPARTAMENTO DE ARTES CENICAS/CCH    M   MESTRADO
#
#    Unnamed: 4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# > Como temos valores Nans, podemos removelos usando` df.drop("Unnamed: 4", axis=1, inplace=True)` ou criando um df de colunas.

# %%
colunas = ['nome', 'unidade', 'sexo', 'titulacao']
# Abrir o URL e ler o CSV diretamente em um DataFrame
response = urllib.request.urlopen(url_2020, context=context)
df = pd.read_csv(response, sep =";",usecols = colunas)
df.head()
# Out:
#                                nome  \
# 0  ALANA DAS CHAGAS FERREIRA AGUIAR
# 1    FREDERICO FERNANDO SOUZA SILVA
# 2     ANDREA MARQUES DA SILVA PIRES
# 3                SARA FITERMAN LIMA
# 4         ABIMAELSON SANTOS PEREIRA
#
#                                             unidade sexo  titulacao
# 0                     DEPARTAMENTO DE BIOLOGIA/CCBS    F  DOUTORADO
# 1                 DEPARTAMENTO DE ARTES VISUAIS/CCH    M  DOUTORADO
# 2                    DEPARTAMENTO DE PATOLOGIA/CCBS    F  DOUTORADO
# 3  COORDENACAO DO CURSO DE MEDICINA PINHEIRO/CCHNST    F  DOUTORADO
# 4                 DEPARTAMENTO DE ARTES CENICAS/CCH    M   MESTRADO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1863 entries, 0 to 1862
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nome       1863 non-null   object
#  1   unidade    1863 non-null   object
#  2   sexo       1863 non-null   object
#  3   titulacao  1863 non-null   object
# dtypes: object(4)
# memory usage: 58.3+ KB

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.describe()
# Out:
#                                     nome                unidade  sexo  \
# count                               1863                   1863  1863
# unique                              1863                     92     2
# top     ALANA DAS CHAGAS FERREIRA AGUIAR  COLEGIO UNIVERSITARIO     M
# freq                                   1                     81   938
#
#         titulacao
# count        1863
# unique          5
# top     DOUTORADO
# freq         1252

# %% [markdown]
# >Primeiro, analise a quantidade de docentes por unidade, listando as 10 unidades que possuem a maior quantidade de docentes. De modo geral, você vai precisar escrever o seguinte algoritmo:

# %%
df.unidade.value_counts().sort_values(ascending=False).head(10)
# Out:
# unidade
# COLEGIO UNIVERSITARIO                                81
# COORDENACAO DO CURSO DE MEDICINA IMPERATRIZ/CCSST    60
# COORDENACAO DO CURSO DE MEDICINA PINHEIRO/CCHNST     57
# DEPARTAMENTO DE LETRAS/CCH                           47
# DEPARTAMENTO DE MEDICINA I/CCBS                      45
# DEPARTAMENTO DE DIREITO/CCSO                         44
# COORDENACAO DO CURSO DE CIENCIA E TECNOLOGIA/CCET    41
# DEPARTAMENTO DE EDUCACAO II/CCSO                     40
# DEPARTAMENTO DE COMUNICACAO SOCIAL/CCSO              40
# DEPARTAMENTO DE CIENCIAS FISIOLOGICAS/CCBS           40
# Name: count, dtype: int64

# %% [markdown]
# A grande quantidade de unidades dificulta a visualização por meio de um gráfico em linhas. Neste caso, um gráfico de barras pode facilitar a leitura dos dados. Para isso, você precisará seguir os seguintes passos:
#
# 1. Para cada titulação, contar os docentes que estão vinculados a ela;
# 2. Para cada titulação, calcular o seu percentual no total;
# 3. Criar um gráfico de barras com esse percentual por titulação.

# %%
df['titulacao'].value_counts(normalize=True).plot(kind='bar',color = 'Black')
# Out:
# <Axes: xlabel='titulacao'>

# %% [markdown]
# Como essa consulta retornou apenas uma docente e já que sabemos que a titulação máxima é “doutorado”, logo podemos corrigir a informação dessa docente (245), mudando sua titulação para 'DOUTORADO'.

# %%
df.loc[245].titulacao = 'DOUTORADO'

# %% [markdown]
# Podemos agora criar uma célula com o mesmo código para visualizar o gráfico novamente:

# %%
df['titulacao'].value_counts(normalize=True).plot(kind='bar', color = 'Black')
# Out:
# <Axes: xlabel='titulacao'>

# %% [markdown]
# Adicionalmente, podemos analisar a quantidade de docentes por sexo e titulação. Nesse caso, vamos analisar duas informações em conjunto para ter uma melhor visão. Pode ser que tenhamos mais docentes do sexo masculino do que feminino ou que os docentes do sexo feminino possuam maior titulação.
#
# Para problemas como esse, existe uma variação do gráfico de barras tradicional: o gráfico de barras empilhadas. Esse método permite visualizar a composição de diferentes categorias dentro de cada barra, contendo várias séries empilhadas umas sobre as outras, em vez de conter apenas uma série de dados por barra. Cada segmento da barra representa uma parte da totalidade, ajudando a mostrar tanto os totais quanto a contribuição de cada categoria para esses totais.
#
# 1. Para cada sexo e titulação, contar a quantidade de docentes;
# 2. Gerar o gráfico de barras empilhadas.
#
# Para criar um gráfico de barras empilhadas, utilizamos o método plot do Pandas com kind='bar' e stacked=True. Contudo, a saída do value_counts não está no formato adequado para o gráfico de barras empilhadas, por isso será necessário utilizarmos o unstiiiiiiack para organizar os dados previamente.

# %%
df.value_counts(['sexo','titulacao']).unstack().plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='sexo'>

# %% [markdown]
# vamos listar as 10 unidades com mais docentes do sexo masculino e repetir o procedimento para o sexo feminino. A diferença agora é que iremos filtrar os docentes pelo sexo, seguindo os seguintes passos:
# 1. Filtrar os docentes do sexo masculino (e/ou feminino);
# 2. Para cada unidade, contar os docentes que estão vinculados a ela;
# 3. Ordenar as unidades pela quantidade de docentes de modo decrescente (do maior para o menor valor);
# 4. Apresentar as 10 primeiras unidades com a quantidade de docentes.

# %%
docentes_masculinos= df.query ( "sexo=='M'").unidade.value_counts()
docentes_femininos = df.query ("sexo=='F'").unidade.value_counts()

# %%
docentes_masculinos.sort_values(ascending=False).head(10)
# Out:
# unidade
# COLEGIO UNIVERSITARIO                                37
# COORDENACAO DO CURSO DE CIENCIA E TECNOLOGIA/CCET    29
# DEPARTAMENTO  DE ENGENHARIA ELETRICA/CCET            28
# COORDENACAO DO CURSO DE MEDICINA PINHEIRO/CCHNST     27
# DEPARTAMENTO DE MATEMATICA/CCET                      27
# DEPARTAMENTO DE DIREITO/CCSO                         27
# DEPARTAMENTO DE MEDICINA I/CCBS                      23
# DEPARTAMENTO DE FILOSOFIA/CCH                        22
# COORDENACAO DO CURSO DE MEDICINA IMPERATRIZ/CCSST    21
# DEPARTAMENTO DE EDUCACAO FISICA/CCBS                 21
# Name: count, dtype: int64

# %%
docentes_femininos.sort_values(ascending=False).head(10)
# Out:
# unidade
# COLEGIO UNIVERSITARIO                                44
# COORDENACAO DO CURSO DE MEDICINA IMPERATRIZ/CCSST    39
# DEPARTAMENTO DE LETRAS/CCH                           37
# DEPARTAMENTO DE EDUCACAO II/CCSO                     32
# COORDENACAO DO CURSO DE MEDICINA PINHEIRO/CCHNST     30
# DEPARTAMENTO DE ENFERMAGEM/CCBS                      30
# DEPARTAMENTO DE CIENCIAS FISIOLOGICAS/CCBS           29
# DEPARTAMENTO DE EDUCACAO I/CCSO                      28
# COORDENACAO DO CURSO DE ENFERMAGEM/CCSST             26
# DEPARTAMENTO DE PSICOLOGIA/CCH                       23
# Name: count, dtype: int64

# %% [markdown]
# ### Analisando os dados dos alunos ingressantes

# %%
import pandas as pd

# %%
import ssl
import urllib.request
import pandas as pd
# Ignorar a verificação do certificado SSL
context = ssl._create_unverified_context()

# URL do arquivo CSV
url_2018_1 = 'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/94c390a1-af05-49df-a42c-de11f1187999/download/alunos_ingressantes_-_2018.1.csv'
# Abrir o URL e ler o CSV diretamente em um DataFrame
response = urllib.request.urlopen(url_2018_1, context=context)
df_disc_2018  = pd.read_csv(response, sep =";")

# %%
df_disc_2018.head()
# Out:
#   municipio               curso          grau       turno  modalidade nivel  \
# 0   BACABAL  LETRAS - PORTUGUÊS  LICENCIATURA  Vespertino  Presencial     G
# 1   BACABAL  LETRAS - PORTUGUÊS  LICENCIATURA  Vespertino  Presencial     G
# 2   BACABAL  LETRAS - PORTUGUÊS  LICENCIATURA  Vespertino  Presencial     G
# 3   BACABAL  LETRAS - PORTUGUÊS  LICENCIATURA  Vespertino  Presencial     G
# 4   BACABAL  LETRAS - PORTUGUÊS  LICENCIATURA  Vespertino  Presencial     G
#
#    habilitacao  convenio                                   forma_ingresso  \
# 0          NaN       NaN                        SISU - AMPLA CONCORRÊNCIA
# 1          NaN       NaN                            SISU - ESCOLA PÚBLICA
# 2          NaN       NaN          SISU - ESCOLA PUBLICA - DEFICIENTE - RF
# 3          NaN       NaN                    SISU - ESCOLA PUBLICA - NEGRO
# 4          NaN       NaN  SISU - ESCOLA PUBLICA - NEGRO - DEFICIENTE - RF
#
#     ano  periodo  quantidade  Unnamed: 12
# ...

# %%
df_disc_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   municipio       417 non-null    object
#  1   curso           417 non-null    object
#  2   grau            417 non-null    object
#  3   turno           417 non-null    object
#  4   modalidade      417 non-null    object
#  5   nivel           417 non-null    object
#  6   habilitacao     0 non-null      float64
#  7   convenio        0 non-null      float64
#  8   forma_ingresso  417 non-null    object
#  9   ano             417 non-null    int64
#  10  periodo         417 non-null    int64
#  11  quantidade      417 non-null    int64
#  12  Unnamed: 12     0 non-null      float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 42.5+ KB

# %%
df_disc_2018.columns
# Out:
# Index(['municipio', 'curso', 'grau', 'turno', 'modalidade', 'nivel',
#        'habilitacao', 'convenio', 'forma_ingresso', 'ano', 'periodo',
#        'quantidade', 'Unnamed: 12'],
#       dtype='object')

# %%
colunas = ['municipio', 'curso', 'grau', 'turno','modalidade', 'nivel','forma_ingresso', 'ano', 'periodo','quantidade']

# %%
df_disc_2018 = pd.read_csv(url_2018_1, sep = ';', usecols = colunas)

# %%
df_disc_2018.sort_values('quantidade')
# Out:
#       municipio                                 curso          grau  \
# 385    SÃO LUÍS                               QUÍMICA   BACHARELADO
# 258    SÃO LUÍS                              FARMÁCIA   BACHARELADO
# 255    SÃO LUÍS  ESTUDOS AFRICANOS E AFRO-BRASILEIROS  LICENCIATURA
# 109    SÃO LUÍS                 CIÊNCIA DA COMPUTAÇÃO   BACHARELADO
# 110    SÃO LUÍS                 CIÊNCIA DA COMPUTAÇÃO   BACHARELADO
# ..          ...                                   ...           ...
# 330    SÃO LUÍS                              MEDICINA   BACHARELADO
# 20   CHAPADINHA                   ENGENHARIA AGRÍCOLA   BACHARELADO
# 231    SÃO LUÍS                      ENGENHARIA CIVIL   BACHARELADO
# 124    SÃO LUÍS                  CIÊNCIA E TECNOLOGIA   BACHARELADO
# 116    SÃO LUÍS                  CIÊNCIA E TECNOLOGIA   BACHARELADO
#
#                               turno  modalidade nivel  \
# 385                      Vespertino  Presencial     G
# ...

# %% [markdown]
# >Ao analisar os dados com mais atenção, identificamos uma quantidade pequena de ingressantes e várias linhas para o mesmo curso. Isso acontece porque existem diferentes formas de ingresso no mesmo semestre.
#
# >Para determinar os 10 cursos com a maior quantidade de ingressantes, precisaremos elaborar um algoritmo com os seguintes passos:
#
# 1. Agrupar as diferentes formas de ingresso por curso;
# 2. Funções matemáticas somar a quantidade de ingressantes de todas as formas de ingresso de cada curso;
# 3. Ordenar de modo decrescente;
# 4. Lsitar os 10 primeiros

# %%
df_disc_2018.groupby('curso')['quantidade'].sum().sort_values(ascending=False).head(10)
# Out:
# curso
# CIÊNCIA E TECNOLOGIA               195
# DIREITO                            123
# MEDICINA                           109
# PEDAGOGIA                          105
# ENFERMAGEM                          92
# CIÊNCIAS BIOLÓGICAS                 77
# EDUCAÇÃO FÍSICA                     76
# COMUNICAÇÃO SOCIAL - JORNALISMO     60
# LETRAS - PORTUGUÊS                  47
# ADMINISTRAÇÃO                       45
# Name: quantidade, dtype: int64

# %% [markdown]
# >Existem cursos ofertados em mais de um turno e município. Para distinguir esses ingressantes, precisamos agrupar por curso, município e turno.

# %%
df_disc_2018.groupby(['curso','municipio','turno'])['quantidade'].sum().sort_values(ascending=False).head(10)
# Out:
# curso                            municipio   turno
# CIÊNCIA E TECNOLOGIA             SÃO LUÍS    Matutino                 98
#                                              Noturno                  97
# MEDICINA                         SÃO LUÍS    Matutino e Vespertino    53
# ENFERMAGEM                       IMPERATRIZ  Matutino e Vespertino    48
# LETRAS - PORTUGUÊS               BACABAL     Vespertino               47
# COMUNICAÇÃO SOCIAL - JORNALISMO  IMPERATRIZ  Vespertino               46
# ADMINISTRAÇÃO                    SÃO LUÍS    Matutino                 45
# DIREITO                          SÃO LUÍS    Matutino                 44
# MATEMÁTICA                       SÃO LUÍS    Vespertino               44
# CIÊNCIAS ECONÔMICAS              SÃO LUÍS    Vespertino               44
# Name: quantidade, dtype: int64

# %% [markdown]
# > Agora vamos unir tudo, usar uma lista e armazenar todas as URLs

# %%
urls =[

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/94c390a1-af05-49df-a42c-de11f1187999/download/alunos_ingressantes_-_2018.1.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/876d6fe4-a5c1-4252-860e-e878733ae85c/download/alunos_ingressantes_-_2018.2.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/75843aa8-951b-464b-8d0e-39fdf62fa79f/download/alunos_ingressantes_-_2019.1.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/42226a8b-5ec4-4886-b372-85cbb56d0496/download/alunos_ingressantes_-_2019.2.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/573a5221-5228-44ee-8857-f4cc33b1ee6a/download/alunos_ingressantes_-_2020.1.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/77ccde1b-7bfe-4342-bcf1-7a5075982d96/download/alunos_ingressantes_-_2020.2.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/61fff8f0-4c95-4293-9921-d3a92d09af26/download/alunos_ingressantes_-_2021-1.csv',

'http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/b473e197-50e5-4c2d-91ff-8bc2291cd9f3/download/alunos_ingressantes_-_2021.2.csv',

]

# %% [markdown]
# > Agora, é preciso escrever um algoritmo que, para cada URL dessa lista, carregue os dados em um único DataFrame. No entanto, antes de desenvolver esse algoritmo, entenda melhor um dos pilares do pensamento computacional.
#
# >Para o nosso problema, iremos fazer algo semelhante, contudo, iremos inicializar df_total com um DataFrame vazio, ao invés de zero. O valor i, nesse caso, será o DataFrame carregado e iremos acumular através da operação pd.concat ( ) em vez da adição. A operação irá gerar o seguinte resultado:
#
# >Vamos criar uma função que irá abstrair o carregamento de múltiplos DataFrames. Copie o código dessa função em uma nova célula e a execute.

# %%
def load_dataframe_by_urls(urls, cols):
  df_total = pd.DataFrame() # inicializa um dataframe vazio
  for url in urls:
    print("url: ",url)
    df = pd.read_csv(url, sep=';', usecols=colunas)
    df_total = pd.concat([df_total, df])
  return df_total

# %%
df_ingressantes = load_dataframe_by_urls(urls, colunas)
# Out:
# url:  http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/94c390a1-af05-49df-a42c-de11f1187999/download/alunos_ingressantes_-_2018.1.csv
# url:  http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/876d6fe4-a5c1-4252-860e-e878733ae85c/download/alunos_ingressantes_-_2018.2.csv
# url:  http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/75843aa8-951b-464b-8d0e-39fdf62fa79f/download/alunos_ingressantes_-_2019.1.csv
# url:  http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/42226a8b-5ec4-4886-b372-85cbb56d0496/download/alunos_ingressantes_-_2019.2.csv
# url:  http://dadosabertos.ufma.br/dataset/36d814e1-baa0-466c-86d8-73714c076755/resource/573a5221-5228-44ee-8857-f4cc33b1ee6a/download/alunos_ingressantes_-_2020.1.csv
# ...

# %% [markdown]
# >Usando compreensão de listas, poderíamos evitar a necessidade da iteração e da função anterior, colocando tudo em duas linhas:

# %%
dfs = [pd.read_csv(url,sep=";", usecols= colunas) for url in urls]
df_final = pd.concat(dfs)

# %%
df_ingressantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3421 entries, 0 to 427
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   municipio       3421 non-null   object
#  1   curso           3421 non-null   object
#  2   grau            3421 non-null   object
#  3   turno           3421 non-null   object
#  4   modalidade      3421 non-null   object
#  5   nivel           3421 non-null   object
#  6   forma_ingresso  3421 non-null   object
#  7   ano             3420 non-null   float64
#  8   periodo         3420 non-null   float64
#  9   quantidade      3420 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 294.0+ KB

# %% [markdown]
# >Com relação à quantidade de entradas, é esperado que sejam carregadas 3421 linhas com 10 colunas. Para as colunas ano, período e quantidade foram carregados 3420 valores não nulos, indicando que temos um valor nulo nessas colunas. Podemos confirmar a quantidade de valores nulos com o seguinte script:

# %%
df_ingressantes['ano'].isna().sum()
# Out:
# 1

# %% [markdown]
# >Podemos remover esse valor diretamente no DataFrame usando o método .dropna e o parâmetro inplace com valor verdadeiro True. Esse parâmetro indica que a mudança deverá ser feita diretamente no DataFrame:

# %%
df_ingressantes.dropna(inplace=True)

# %%
df_ingressantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3420 entries, 0 to 427
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   municipio       3420 non-null   object
#  1   curso           3420 non-null   object
#  2   grau            3420 non-null   object
#  3   turno           3420 non-null   object
#  4   modalidade      3420 non-null   object
#  5   nivel           3420 non-null   object
#  6   forma_ingresso  3420 non-null   object
#  7   ano             3420 non-null   float64
#  8   periodo         3420 non-null   float64
#  9   quantidade      3420 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 293.9+ KB

# %% [markdown]
# >Contudo, as colunas ano, período e quantidade foram carregados como float64 em vez de int32.
#
# >Em casos similares a esse, podemos converter o tipo de dados das colunas através do método `.astype()`. Este método recebe um dicionário em que a chaves são as colunas e os valores são os tipos de dados para os quais desejamos converter.

# %%
df_ingressantes = df_ingressantes.astype(

                                         {'ano':'int32','periodo':'int32','quantidade':'int32'}
)

# %%
df_ingressantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3420 entries, 0 to 427
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   municipio       3420 non-null   object
#  1   curso           3420 non-null   object
#  2   grau            3420 non-null   object
#  3   turno           3420 non-null   object
#  4   modalidade      3420 non-null   object
#  5   nivel           3420 non-null   object
#  6   forma_ingresso  3420 non-null   object
#  7   ano             3420 non-null   int32
#  8   periodo         3420 non-null   int32
#  9   quantidade      3420 non-null   int32
# dtypes: int32(3), object(7)
# memory usage: 253.8+ KB

# %% [markdown]
# >Quando olhamos o dado de um semestre, observamos que existem casos em que o mesmo curso é ofertado em diferentes municípios e turnos. Um exemplo é o curso “Ciência e Tecnologia” , ofertado em dois turnos em São Luís e um turno em Balsas, cada oferta com diferentes formas de ingresso.
#
# >Para facilitar essa distinção, vamos criar uma coluna que terá o nome do município e o turno para compor o nome do curso:

# %%
df_ingressantes['nome_completo'] = df_ingressantes['curso'] + ' - ' + df_ingressantes['municipio'] + ' - ' + df_ingressantes['turno']

# %%
df_ingressantes['nome_completo']
# Out:
# 0      LETRAS - PORTUGUÊS - BACABAL - Vespertino
# 1      LETRAS - PORTUGUÊS - BACABAL - Vespertino
# 2      LETRAS - PORTUGUÊS - BACABAL - Vespertino
# 3      LETRAS - PORTUGUÊS - BACABAL - Vespertino
# 4      LETRAS - PORTUGUÊS - BACABAL - Vespertino
#                          ...
# 423                TURISMO - SÃO LUÍS - Matutino
# 424                TURISMO - SÃO LUÍS - Matutino
# 425                TURISMO - SÃO LUÍS - Matutino
# 426                TURISMO - SÃO LUÍS - Matutino
# 427                TURISMO - SÃO LUÍS - Matutino
# Name: nome_completo, Length: 3420, dtype: object

# %% [markdown]
# > assim, o valor dessa nova coluna será distinto para cada oferta. Além disso, iremos incluir apenas os dados de cursos presenciais nessa análise. Para isso, adicione e execute o seguinte script em uma nova célula:

# %%
df_presencial = df_ingressantes.query("modalidade == 'Presencial'")

# %% [markdown]
# >Com os dados preparados, podemos calcular a média de ingressantes, como proposto no início desta seção. Nesse ponto, você já deve imaginar que vamos usar a função groupby() e, na agregação, calcular a média com a função mean(). Logo, podemos tentar algo como:

# %%
df_presencial.groupby('nome_completo')['quantidade'].mean().head(10)
# Out:
# nome_completo
# ADMINISTRAÇÃO - SÃO LUÍS - Matutino                         6.535714
# AGRONOMIA - CHAPADINHA - Matutino e Vespertino              6.578947
# ARTES VISUAIS - SÃO LUÍS - Matutino                         4.512821
# BIBLIOTECONOMIA - SÃO LUÍS - Matutino                       6.568627
# CIÊNCIA DA COMPUTAÇÃO - SÃO LUÍS - Vespertino               6.760000
# CIÊNCIA DA COMPUTAÇÃO - SÃO LUÍS - Vespertino e Noturno     6.407407
# CIÊNCIA E TECNOLOGIA - BALSAS - Matutino                    6.714286
# CIÊNCIA E TECNOLOGIA - BALSAS - Noturno                     7.047619
# CIÊNCIA E TECNOLOGIA - SÃO LUÍS - Matutino                 15.271186
# CIÊNCIA E TECNOLOGIA - SÃO LUÍS - Noturno                  13.075758
# Name: quantidade, dtype: float64

# %% [markdown]
# >Olhando o resultado, parece estranho haver cursos com média de alunos abaixo de 10. Outro ponto que chama atenção é o curso Ciência e Tecnologia estar com uma média de 15 alunos. Para quem conhece a Universidade, sabe que esse curso abre semestralmente 120 vagas em cada turno.
#
# >Quando precisamos desenvolver algoritmos mais complexos, pode ser necessário fazer um rascunho antes de começar a escrevê-los. Convido você a fazer um rascunho desses algoritmos antes de ver a solução.
#
# >Em alto nível, temos o seguinte algoritmo:
# 1. Agrupar os cursos por ano e semestre;
# 2. Para cada curso, somar a quantidade de ingressantes, para obter a quantidade de ingressantes no semestre – neste passo, somaremos a quantidade de ingressantes das distintas formas de ingresso;
# 3. Tendo a quantidade de ingressantes por semestre,
# agrupe-os para calcular a média do curso;
# 4. Ordenar de modo decrescente e listar os 10 cursos
# com maior quantidade de ingressantes.
#
# >Para esse problema, iremos salvar alguns resultados intermediários para que possamos compreender melhor o efeito dessas operações. Vamos executar e visualizar a saída para os dois primeiros passos:

# %%
grupo = ['nome_completo','ano', 'periodo']
df_por_semestre = df_presencial.groupby(grupo)['quantidade'].sum()
df_por_semestre.head(10)
# Out:
# nome_completo                                   ano   periodo
# ADMINISTRAÇÃO - SÃO LUÍS - Matutino             2018  1          45
#                                                       2          55
#                                                 2019  1          47
#                                                       2          46
#                                                 2020  1          36
#                                                       2          41
#                                                 2021  1          49
#                                                       2          47
# AGRONOMIA - CHAPADINHA - Matutino e Vespertino  2018  1          38
#                                                       2          33
# Name: quantidade, dtype: int32

# %% [markdown]
# >Em seguida, poderemos ordenar de modo decrescente e listar os 10 cursos com maior quantidade de ingressantes:

# %%
media_por_curso = df_por_semestre.groupby('nome_completo').mean()
media_por_curso.sort_values(ascending=False).head(10)
# Out:
# nome_completo
# CIÊNCIA E TECNOLOGIA - SÃO LUÍS - Matutino                      112.625
# CIÊNCIA E TECNOLOGIA - SÃO LUÍS - Noturno                       107.875
# PEDAGOGIA - GRAJAÚ - Matutino e Vespertino                       84.000
# PEDAGOGIA - LAGO DA PEDRA - Matutino e Vespertino                70.000
# HISTÓRIA - LAGO DO JUNCO - Matutino e Vespertino                 60.000
# PEDAGOGIA - LAGOA GRANDE DO MARANHÃO - Matutino e Vespertino     59.000
# PEDAGOGIA - BURITI BRAVO - Matutino e Vespertino                 59.000
# PEDAGOGIA - URBANO SANTOS - Matutino e Vespertino                58.000
# CIÊNCIAS NATURAIS - BIOLOGIA - PINHEIRO - Noturno                57.750
# CIÊNCIAS HUMANAS - SOCIOLOGIA - SÃO BERNARDO - Noturno           57.500
# Name: quantidade, dtype: float64

# %% [markdown]
# > Ordenando com as menores médias

# %%
media_por_curso.sort_values(ascending=True).head(10)
# Out:
# nome_completo
# GEOGRAFIA - MARACAÇUMÉ - Matutino e Vespertino                            1.000
# ENGENHARIA ELÉTRICA - BALSAS - Vespertino e Noturno                       1.000
# ENGENHARIA AMBIENTAL - BALSAS - Vespertino e Noturno                      3.000
# CIÊNCIAS EXATAS - CENTRAL DO MARANHÃO - Matutino, Vespertino e Noturno    3.000
# ENGENHARIA AEROESPACIAL - SÃO LUÍS - Noturno                              4.000
# ENGENHARIA MECÂNICA - SÃO LUÍS - Matutino e Vespertino                    5.375
# MÚSICA - SÃO LUÍS - Matutino e Vespertino                                 6.000
# ENGENHARIA AMBIENTAL E SANITÁRIA - SÃO LUÍS - Matutino e Vespertino       7.375
# CIÊNCIAS EXATAS - PINDARÉ-MIRIM - Matutino, Vespertino e Noturno          9.000
# LETRAS - FRANCÊS - SÃO LUÍS - Matutino                                    9.375
# Name: quantidade, dtype: float64

# %%
media_por_curso.sort_values(ascending=True).head(10)
# Out:
# nome_completo
# GEOGRAFIA - MARACAÇUMÉ - Matutino e Vespertino                            1.000
# ENGENHARIA ELÉTRICA - BALSAS - Vespertino e Noturno                       1.000
# ENGENHARIA AMBIENTAL - BALSAS - Vespertino e Noturno                      3.000
# CIÊNCIAS EXATAS - CENTRAL DO MARANHÃO - Matutino, Vespertino e Noturno    3.000
# ENGENHARIA AEROESPACIAL - SÃO LUÍS - Noturno                              4.000
# ENGENHARIA MECÂNICA - SÃO LUÍS - Matutino e Vespertino                    5.375
# MÚSICA - SÃO LUÍS - Matutino e Vespertino                                 6.000
# ENGENHARIA AMBIENTAL E SANITÁRIA - SÃO LUÍS - Matutino e Vespertino       7.375
# CIÊNCIAS EXATAS - PINDARÉ-MIRIM - Matutino, Vespertino e Noturno          9.000
# LETRAS - FRANCÊS - SÃO LUÍS - Matutino                                    9.375
# Name: quantidade, dtype: float64

# %% [markdown]
# >Convido você a seguir fazendo novas perguntas, por exemplo: poderíamos incluir apenas os cursos cujo ingresso tenha sido feito via SISU? Mas isso é só um exemplo. Continue explorando esses dados e busque outros dados no portal da UFMA e de outras fontes.
